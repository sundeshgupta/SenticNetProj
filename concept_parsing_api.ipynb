# %%
# importing the requests library
import requests
import pandas as  pd
import pickle
import re

# %%
data = pd.read_csv('./gold_raw.csv')

# tweets = data['tweet'].tolist()

# %%
data[data['id'] == 1369812663623180288]['tweet']
# Out:
# 0    In great news my senior parents are getting th...
# Name: tweet, dtype: object

# %%
# api-endpoint
ENDPOINT = "https://sentic.net/api/en/"

# %%
POLARITY_KEY = 'cUbp4rw1fo.py'

# %%
URL = ENDPOINT + POLARITY_KEY

# %%
# location given here
# text = "I've had my 2nd dose of Covid :Vaccine. I got myself vaccinated to protect my service , my colleagues and myself. As a doctor I am convinced of its safety and efficacy and would encourage everyone else to take up the opportunity to get the vaccine too when it is offered"
text = "In great news my senior parents are getting the vaccine tomorrow. <EMOJI:red_heart> Whew, thank goodness. #vaccine"
# defining a params dict for the parameters to be sent to the API

for c in [';', '&', '#']: 
    text = text.replace(c, ':')
    text = re.sub('<EMOJI[\S]*>', '', text)
    text = re.sub('<USER>', '', text)
    
PARAMS = {'text':text}
  
# sending get request and saving the response as response object
r = requests.get(url = URL, params = PARAMS)
print(r.text)
# Out:
# ['great news', 'senior', 'vaccine', 'thank', 'goodness', 'vaccine']

# %%
import asyncio
import aiohttp

# %%
outputs = []
cnt = 0

def preprocess(text):
    for c in [';', '&', '#']: 
        text = text.replace(c, ':')
    text = re.sub('<EMOJI[\S]*>', '', text)
    text = re.sub('<USER>', '', text)
    return text

async def get(session, text, id):
    try:
        async with session.get(url=URL, params = {'text':preprocess(text)}) as response:
            resp = await response.read()
            return [id, resp]
    except Exception as e:
        print("Unable to get url due to {}.".format(e.__class__))


async def main(data):
    async with aiohttp.ClientSession() as session:
        ret = await asyncio.gather(*[get(session, row['tweet'], row['id']) for idx, row in data.iterrows()])
    print("Finalized all. Return is a list of len {} outputs.".format(len(ret)))
    # print(ret)
    outputs.extend(ret)

# l = len(tweets)
loop = asyncio.get_event_loop()
loop.run_until_complete(main(data))
# fl = open('outputs', 'wb')
# pickle.dump(outputs, fl)
# Out:
# Finalized all. Return is a list of len 2000 outputs.

# %%
outputs
# Out:
# [[1369812663623180288,
#   b"['great news', 'senior', 'vaccine', 'thank', 'goodness', 'vaccine']\n"],
#  [1354514776534220804,
#   b"['founder', 'recent', 'covid', 'vaccine', 'vaccine', 'spread', 'awareness', 'vaccine', 'effective', 'safe', 'best', 'tool', 'against', 'covid']\n"],
#  [1349045265945264130,
#   b"['fail', 'make', 'vaccine', 'priority', 'plus', 'spread', 'covid', 'vaccine', 'dose']\n"],
#  [1366793773728980992,
#   b"['cared', 'stop', 'punch', 'plane', 'traitor', 'vaccine']\n"],
#  [1365339417997623296,
#   b"['dose', 'rate', 'increase', 'rate', 'increase', 'average', 'average', 'rise', 'vaccine', 'covid']\n"],
#  [1358108212055203844,
#   b"['nuclear energy', 'winning', 'awake', 'giant', 'magnet', 'talent', 'entrepreneur', 'fastest', 'vaccine', 'roll']\n"],
#  [1371004616897269763,
#   b"['health care', 'risk', 'turn', 'vaccine', 'vaccine', 'basically', 'worker', 'know', 'vaccine']\n"],
#  [1356666221450690560,
#   b"['great', 'call', 'roll', 'vaccine', 'good', 'hear', 'opening', 'vaccine', 'cent', 'covid', 'vaccine']\n"],
#  [1352375432214142978,
#   b"['christmas eve', 'tested positive', 'mage', 'colleague', 'vaccine', 'vaccine', 'late', 'covid', 'vaccine', 'ok']\n"],
#  [1357212378765684738,
#   b"['offering', 'vaccine', 'vaccine', 'leading', 'inoculation', 'effort', 'time', 'cabinet', 'discuss', 'hang']\n"],
#  [1356389129781673985,
#   b"['call', 'suffered', 'vaccine', 'effect', 'report', 'govern', 'report', 'injury']\n"],
#  [1361768521949192198,
#   b"['covid', 'covid', 'vaccine', 'political', 'gallery']\n"],
#  [1371143426599702528,
#   b"['good health', 'wish', 'end', 'hideous', 'pandemic', 'covid', 'vaccine']\n"],
#  [1364394016406712324,
#   b"['liberal', 'mantra', 'choice', 'vaccine', 'exclusive', 'murder']\n"],
#  [1375851778340749313,
#   b"['alternate', 'help', 'answer', 'expected', 'surplus', 'covid', 'vaccine', 'quickly']\n"],
#  [1361389133231517699,
#   b"['brain dead', 'stop', 'reject', 'covid', 'vaccine', 'old', 'healthcare', 'worker', 'aneurysm', 'experiment', 'covid', 'injection']\n"],
#  [1347738564688281600,
#   b"['look forward', 'believe', 'brigade', 'lost', 'follower', 'hopefully', 'vax', 'sticking', 'enjoying', 'discourse', 'covid', 'vaccine']\n"],
#  [1353294168039313409,
#   b"['deliberately mislead', 'vaccine', 'achieve', 'dose', 'lie', 'vaccine', 'vaccine', 'covid', 'covid', 'covid']\n"],
#  [1345743906705715201,
#   b"['vaccine', 'test', 'know', 'tell', 'spread', 'widely', 'covid', 'vaccine', 'animal', 'meane', 'animal', 'happy', 'see', 'follow']\n"],
#  [1345934230006726656,
#   b"['chief', 'approximately', 'vaccine', 'houre', 'sunday']\n"],
#  [1359788707780448257, b"['diversified', 'vaccine', 'dose', 'expected']\n"],
#  [1360652918718926857,
#   b"['provincial', 'grand', 'master', 'covid', 'vaccine', 'say', 'covid', 'vaccine']\n"],
#  [1368999260767875085,
#   b"['specific', 'patient', 'decision', 'tool', 'covid', 'vaccine', 'pregnant', 'individual', 'released']\n"],
#  [1362147355458379778,
#   b"['chance', 'honor', 'friends', 'old', 'moth', 'covid', 'vaccine', 'take']\n"],
#  [1355229898240045062,
#   b"['big boy', 'food supply', 'bad idea', 'door', 'economy', 'vaccine']\n"],
#  [1369697112728895491,
#   b"['govern', 'vaccine', 'assistance', 'tote', 'report', 'covid']\n"],
#  [1347548987780460545,
#   b"['important', 'information', 'regard', 'coronavirus', 'vaccine', 'relate', 'safe', 'stay', 'vigilant', 'scammers', 'affected']\n"],
#  [1368909636787703816,
#   b"['on time', 'complicated', 'categories', 'open', 'vaccine', 'coronavirus', 'covid']\n"],
#  [1355518832849416195,
#   b"['great', 'short', 'vaccine', 'share', 'lots', 'language', 'helpful', 'thread']\n"],
#  [1363391701193138178,
#   b"['rape allegation', 'join', 'discuss', 'vaccine', 'rollout', 'beg', 'fallout', 'special', 'report']\n"],
#  [1358009201960906753, b"['nice', 'opening', 'doors', 'vaccine']\n"],
#  [1362382278584918016,
#   b"['grandmother', 'basically', 'cause', 'late', 'assure', 'brother', 'covid', 'vaccine', 'realize', 'stressed', 'love']\n"],
#  [1358891343049879554,
#   b"['well done', 'successful', 'delivery', 'vaccine', 'involve', 'effort']\n"],
#  [1375115950371057664,
#   b"['requisite', 'dose', 'vaccine', 'turn', 'yall', 'vaccine', 'covid']\n"],
#  [1351218916991893505, b"['kingdom', 'comment', 'covid', 'vaccine']\n"],
#  [1371857270573838337,
#   b"['grateful', 'continuous', 'support', 'critical', 'time', 'fight', 'coronavirus', 'normality', 'vaccine', 'vaccine']\n"],
#  [1353875661845311488,
#   b"['sign up', 'covid', 'vaccine', 'created', 'vaccine', 'open', 'operate', 'call', 'toll', 'free']\n"],
#  [1352620163804364802,
#   b"['fear', 'needle', 'prevent', 'vaccine', 'offering', 'free', 'session', 'via', 'zoom', 'help', 'needle', 'vaccine']\n"],
#  [1349033098164498433,
#   b"['vaccine', 'population', 'end', 'leadership', 'work', 'covid', 'vaccine']\n"],
#  [1357740656483946499,
#   b"['vaccine', 'study', 'vaccine', 'manufacture', 'science', 'advertising']\n"],
#  [1345629238557253637,
#   b"['leading', 'vaccine', 'available', 'take', 'covid', 'vaccine']\n"],
#  [1349067518258806784,
#   b"['division', 'direct', 'dose', 'covid', 'vaccine', 'faculty', 'trainee', 'vaccine', 'follow', 'guidance']\n"],
#  [1355470050992467970,
#   b"['wait', 'vaccine', 'appointment', 'cancelled', 'vaccine', 'appointment', 'ready', 'hospital', 'appointment', 'vaccine']\n"],
#  [1347575993490415619,
#   b"['faux', 'crisis', 'govern', 'epic', 'vaccine', 'debacle']\n"],
#  [1346791931800649728,
#   b"['senior', 'ioc', 'outcry', 'athlete', 'prioritise', 'coronavirus', 'vaccine', 'ensure', 'take']\n"],
#  [1359548657347948549,
#   b"['economic recovery', 'help', 'covid', 'vaccine', 'clime', 'change', 'discuss', 'covid', 'coronavirus', 'vaccine']\n"],
#  [1344992897448497154, b"['charge', 'vaccine', 'rollout']\n"],
#  [1361767370373660686,
#   b"['covid', 'update', 'reminder', 'vaccine', 'updated', 'report', 'older', 'population', 'dose', 'take', 'look']\n"],
#  [1362731479214788613,
#   b"['step in', 'congratulations', 'collaborator', 'work', 'significant', 'untangle', 'jungle', 'vaccine']\n"],
#  [1370536654360866816,
#   b"['dose', 'vaccine', 'turn', 'help', 'fight', 'covid', 'vaccine']\n"],
#  [1346058139808968704,
#   b"['kick off', 'new', 'latest', 'vaccine', 'support', 'adapted', 'assay', 'sample', 'refinement', 'early', 'vaccine', 'efficacy', 'testing']\n"],
#  [1374029741972463620,
#   b"['privatize', 'vaccine', 'cut', 'research', 'grants', 'vaccine', 'research', 'vaccine', 'dumb', 'stead', 'dose', 'died', 'nitwit']\n"],
#  [1369284571532042243,
#   b"['conflict', 'vaccine', 'covid', 'free', 'call', 'wreck', 'nice', 'house']\n"],
#  [1370775282290995204,
#   b"['thank', 'healthcare', 'responder', 'happy', 'dose', 'vaccine', 'covid', 'vaccine']\n"],
#  [1353582924109500416,
#   b"['ready to', 'roll', 'show', 'hear', 'vaccine', 'live']\n"],
#  [1374157867637432326,
#   b"['thank', 'science', 'thank', 'pharmacy', 'thank', 'amazing', 'sticker', 'vaccine']\n"],
#  [1362790043757260801,
#   b"['keeps', 'vaccine', 'misunderstanding', 'knowe', 'peoples', 'response', 'covid', 'vaccine']\n"],
#  [1355471682694225921,
#   b"['privileged position', 'life threatening', 'coincidence', 'know', 'spoken', 'vaccine', 'mask', 'illness', 'severely', 'compromised', 'immune', 'system', 'vaccine', 'covid']\n"],
#  [1347139521398386688,
#   b"['young', 'hospital', 'covid', 'vaccine', 'show', 'colleague', 'allowed', 'say', 'proud', 'mama', 'vaccine']\n"],
#  [1353367120805912578,
#   b"['green light', 'strong', 'vaccine', 'puzzling', 'wrong', 'vaccine', 'phase', 'available', 'covid', 'vaccine']\n"],
#  [1354186238714990592,
#   b"['move', 'vaccine', 'older', 'income', 'group', 'excite', 'grateful', 'covid', 'vaccine', 'come', 'challenges', 'supply', 'variant', 'smile', 'laughs']\n"],
#  [1375235563788374026, b"['poetry', 'risen', 'new', 'vaccine']\n"],
#  [1363521443527557125,
#   b"['covid', 'updated', 'sunday', 'new', 'death', 'within', 'positive', 'test', 'report', 'tote', 'dose', 'vaccine']\n"],
#  [1353747837293637634,
#   b"['work', 'covid', 'vaccine', 'come', 'join', 'free']\n"],
#  [1376447797109604354,
#   b"['remind', 'paid', 'vaccine', 'tell', 'consider', 'create', 'vaccine']\n"],
#  [1355277793236496386,
#   b"['mum', 'vaccine', 'rolled', 'electric', 'time', 'happy', 'full', 'hope', 'hard', 'vaccine']\n"],
#  [1355504027937755137,
#   b"['first day', 'observational', 'dose', 'covid', 'vaccine', 'confirmed', 'infection', 'immunization', 'compare', 'rate', 'print']\n"],
#  [1350164268713345024,
#   b"['good news', 'great uncle', 'boyd', 'oldest', 'old', 'covid', 'vaccine', 'veteran', 'hope', 'continue', 'see', 'covid', 'vaccine']\n"],
#  [1361412061499187207,
#   b"['sign', 'remind', 'covid', 'covid', 'vaccine', 'political', 'gallery']\n"],
#  [1371218724359839746,
#   b"['vaccine', 'say', 'okay', 'good', 'complaint', 'conclude', 'arm']\n"],
#  [1360790656092889089,
#   b"['take nap', 'big deal', 'good shape', 'update', 'houre', 'covid', 'vaccine', 'arm', 'sore', 'tired', 'houre', 'ok', 'fatigued', 'mind', 'runner', 'vaccine']\n"],
#  [1367909951461548044,
#   b"['great', 'ask', 'encouraging', 'health', 'check', 'clothes', 'peg', 'covid', 'vaccine']\n"],
#  [1352924110205014017,
#   b"['informed consent', 'signature', 'vaccine', 'trial', 'participant', 'died', 'ration', 'check', 'viscera', 'report']\n"],
#  [1368888956478193666,
#   b"['vaccine', 'teach', 'covid', 'vaccine', 'optimistic', 'grateful']\n"],
#  [1372892159016370178,
#   b"['good opportunity', 'write', 'covid', 'vaccine', 'decision', 'block', 'export', 'destined']\n"],
#  [1367158529505824770,
#   b"['thrilled', 'share', 'fantastic', 'rival', 'collaborate', 'speed', 'vaccine']\n"],
#  [1364770679137079296,
#   b"['fever', 'pain', 'ache', 'weakness', 'heavy', 'chest', 'nausea', 'vaccine', 'tell', 'fever', 'nausea']\n"],
#  [1348806243238887425,
#   b"['huge', 'vaccine', 'rollout', 'beg', 'batch', 'vaccine', 'locate']\n"],
#  [1367597734266601474,
#   b"['awareness', 'kung', 'shares', 'vaccine', 'important', 'vaccine', 'prevent', 'cancer']\n"],
#  [1375407811119742979,
#   b"['important', 'importance', 'behavioural', 'science', 'early', 'covid', 'vaccine', 'research', 'show', 'trust', 'significant', 'predictor', 'covid', 'vaccine', 'covid', 'vaccine']\n"],
#  [1371612689395560452, b"['chippy', 'informed', 'hold', 'vaccine']\n"],
#  [1358460604256813061,
#   b"['ultra cold', 'access', 'chain', 'equipment', 'explain', 'importance', 'transport', 'distribute', 'new', 'covid', 'vaccine', 'learn', 'helping']\n"],
#  [1348240446053634059,
#   b"['waiting line', 'hugely', 'disappointed', 'good', 'deliver', 'baby', 'happily', 'push', 'queue', 'accept', 'vaccine', 'knowe', 'shameful']\n"],
#  [1347500652465852416,
#   b"['vaccine', 'take', 'immediately', 'boost', 'confidence', 'vaccine']\n"],
#  [1353742848772943875,
#   b"['new', 'speed', 'vaccine', 'rollout', 'wales', 'lead', 'wales', 'dropped', 'nation', 'weekend', 'lag', 'average', 'tote', 'vaccine']\n"],
#  [1376555638256377856,
#   b"['to do', 'proof', 'hurt', 'blood', 'hurt', 'vaccine']\n"],
#  [1358398861086232578,
#   b"['vaccine', 'donation', 'army', 'come', 'together', 'achieve', 'via']\n"],
#  [1354380045826060288,
#   b"['good wit', 'mum', 'hate', 'top', 'jumper', 'mask', 'vaccine', 'time', 'needle', 'vaccine', 'mum']\n"],
#  [1375511328161329153,
#   b"['employees', 'welcomed', 'chance', 'covid', 'vaccine', 'clinic', 'responder']\n"],
#  [1355580401239158784,
#   b"['clash', 'covid', 'vaccine', 'political', 'gallery']\n"],
#  [1375365337923850241,
#   b"['green light', 'depute', 'dam', 'report', 'voluntarily', 'take', 'trial', 'covid', 'vaccine', 'expected', 'production', 'quart']\n"],
#  [1366045136338247680, b"['revolution', 'torn', 'vaccine']\n"],
#  [1346875745495355393,
#   b"['victory', 'drive', 'make', 'possible', 'implement', 'say', 'charge', 'covid', 'vaccine', 'rollout']\n"],
#  [1355084682283671565,
#   b"['vaccine', 'create', 'procurement', 'manufacture', 'success', 'played', 'hound', 'step', 'late']\n"],
#  [1350874138026639360,
#   b"['vaccine', 'live', 'celebrating', 'covid', 'vaccine']\n"],
#  [1352619924166856708,
#   b"['laureate', 'join', 'discuss', 'boost', 'vaccine', 'uptake', 'amid', 'covid']\n"],
#  [1348700976333647874,
#   b"['great', 'achievement', 'journo', 'brief', 'matt', 'supply', 'vaccine', 'hint', 'problem', 'reaching', 'mid', 'target', 'covid', 'vaccine']\n"],
#  [1358751428240637953,
#   b"['know', 'vaccine', 'curious', 'supported', 'tenant', 'wanted', 'know', 'help', 'craft', 'research', 'follow', 'vaccine', 'covid']\n"],
#  [1367517055579271168, b"['ask', 'study', 'vaccine', 'response', 'covid']\n"],
#  [1370013093498126344,
#   b"['impact on', 'thanks', 'excellent', 'algorithm', 'working', 'range', 'covid', 'vaccine', 'management', 'bad', 'head', 'aching', 'diabetes', 'control']\n"],
#  [1352866715193864194,
#   b"['batch', 'covid', 'vaccine', 'vial', 'brought', 'covid', 'covid', 'coronavirus', 'vaccine']\n"],
#  [1351647337404366848, b"['sister', 'covid', 'vaccine']\n"],
#  [1347524458760843264,
#   b"['encouraging', 'approval', 'vaccine', 'vaccine', 'works', 'vaccine', 'approved', 'covid', 'vaccine']\n"],
#  [1364975015029075968,
#   b"['dose', 'rate', 'increase', 'rate', 'decrease', 'average', 'slowly', 'expected', 'historic', 'weekly', 'pattern', 'vaccine', 'covid']\n"],
#  [1374035646797516808,
#   b"['encouraged', 'released', 'regard', 'covid', 'vaccine', 'hopeful', 'resource', 'fight', 'end', 'pandemic']\n"],
#  [1371898486896099334,
#   b"['suffering from', 'decision', 'european', 'medical', 'ground', 'decision', 'political', 'ground', 'hang', 'population', 'desperate', 'vaccine']\n"],
#  [1363146542790623237,
#   b"['grateful', 'receiving', 'covid', 'helping', 'protect', 'great', 'organise', 'merchandise', 'covid', 'vaccine']\n"],
#  [1373031082564665345,
#   b"['cardiac arrest', 'defibrillator', 'recent', 'occur', 'healthcare', 'covid', 'vaccine', 'saved', 'vaccine', 'dramatically']\n"],
#  [1365209864377614336,
#   b"['racism', 'vaccine', 'hesitancy', 'vaccine', 'friends', 'family', 'dose', 'vaccine', 'last', 'racism', 'vaccine']\n"],
#  [1374930176807559174, b"['arm', 'vaccine', 'pharmacy']\n"],
#  [1359141753270411264,
#   b"['tested positive', 'dose', 'vaccine', 'individual', 'antibody', 'response', 'greater', 'dose', 'individual', 'infected', 'coronavirus', 'covid']\n"],
#  [1346934734933393408,
#   b"['first day', 'well done', 'dose', 'vaccine', 'efficient', 'vaccine', 'delighted', 'vaccine', 'better', 'protect', 'care', 'vaccine']\n"],
#  [1347159694457139200,
#   b"['new', 'study', 'arm', 'photograph', 'vaccine', 'achieve', 'higher', 'covid', 'vaccine', 'efficacy', 'ternate', 'trial', 'vaccine']\n"],
#  [1352261535612080128,
#   b"['senior citizen', 'low', 'pole', 'highest', 'risk', 'isolation', 'quarantine', 'knowe', 'live', 'terminal', 'lonely', 'harder', 'moderate', 'risk', 'phase', 'vaccine', 'covid']\n"],
#  [1360262984585592832,
#   b"['dose', 'rate', 'increase', 'rate', 'decrease', 'average', 'rate', 'dose', 'time', 'rollout', 'vaccine']\n"],
#  [1351610886247604225,
#   b"['ask', 'buy', 'vaccine', 'dose', 'directly', 'saying', 'release', 'dose']\n"],
#  [1347216035938754565,
#   b"['vaccine', 'lovely', 'formerly', 'vaccine', 'covid']\n"],
#  [1356690547705077764,
#   b"['great news', 'update', 'federal', 'govern', 'covid', 'vaccine', 'pharmacy', 'assure', 'risk', 'work', 'vaccine', 'needed', 'expected', 'govern']\n"],
#  [1353187727240474627,
#   b"['support staff', 'implement', 'fastest', 'rollout', 'vaccine', 'drive', 'vaccine', 'nation', 'together', 'compliment', 'civil', 'inspiration', 'health', 'virus']\n"],
#  [1372305708281171972,
#   b"['critical', 'properly', 'neutralization', 'detectable', 'know', 'clinical', 'impact', 'vaccine', 'hope', 'fuel', 'anxiety', 'hurt', 'vaccine', 'uptake']\n"],
#  [1375651952407683077, b"['lame', 'vaccine', 'rollout', 'say']\n"],
#  [1366142597970984963, b"['vaccine', 'houre', 'shiver', 'kick', 'proud']\n"],
#  [1369364564513599502,
#   b"['immune response', 'vaccine', 'improves', 'lower', 'incidence', 'ecological', 'epidemiological', 'studies', 'tap', 'vaccine']\n"],
#  [1350131539611410435,
#   b"['vaccine', 'happy', 'hugely', 'grateful', 'rolled', 'hope', 'quickly', 'safely', 'covid', 'vaccine']\n"],
#  [1372859458251014144,
#   b"['g spot', 'effects', 'sore', 'arm', 'cheek', 'great', 'chat', 'cyclist', 'vaccine']\n"],
#  [1363202334457790466,
#   b"['reflect', 'noticing', 'unexpected', 'vaccine', 'stead', 'questioning', 'uncomfortable', 'vaccine']\n"],
#  [1350467845109415936,
#   b"['covid', 'healthcare', 'army', 'vaccine', 'vaccine', 'vaccine']\n"],
#  [1361874269995556871,
#   b"['happy', 'new', 'print', 'covid', 'vaccine', 'extremism']\n"],
#  [1355451630720790531,
#   b"['moan', 'rabid', 'moan', 'last', 'houre', 'sell', 'soul', 'parcel', 'money', 'laundering', 'vaccine', 'success']\n"],
#  [1349694286124744704,
#   b"['european', 'medicine', 'approve', 'vaccine', 'make', 'vaccine', 'rate']\n"],
#  [1375862528132136962,
#   b"['deeply grateful', 'folk', 'privilege', 'spectacular', 'view', 'drive', 'vaccine']\n"],
#  [1373143214203437060,
#   b"['way to celebrate', 'fun', 'dose', 'covid', 'vaccine', 'better', 'honoring', 'animal', 'played', 'crucial', 'rule', 'pharmaceutical', 'crab', 'vaccine']\n"],
#  [1368530923927592962,
#   b"['authority', 'suspended', 'administration', 'vaccine', 'report', 'death']\n"],
#  [1348939414286848000,
#   b"['potential', 'vaccine', 'against', 'excellent', 'hope', 'make', 'covid', 'vaccine']\n"],
#  [1349755987029319683,
#   b"['work on', 'thrilled', 'share', 'direct', 'receiving', 'vaccine', 'covid', 'vaccine', 'clinic', 'supporting', 'covid', 'assessment', 'testing', 'vaccine']\n"],
#  [1363183432071663616,
#   b"['new', 'studies', 'show', 'vaccine', 'greatly', 'amplify', 'antibody', 'coronavirus']\n"],
#  [1366204893912993792,
#   b"['covid', 'vaccine', 'sister', 'vaccine', 'population']\n"],
#  [1353586136367554562,
#   b"['know', 'largest', 'vaccine', 'drive', 'against', 'vaccine', 'virus']\n"],
#  [1352588638048178178,
#   b"['covid', 'vaccine', 'cancer', 'care', 'roundtable', 'risk', 'balance', 'ratio', 'covid', 'vaccine', 'cancer', 'treatment', 'favor', 'benefit', 'cancer', 'treatment', 'vaccine']\n"],
#  [1374545982021455873,
#   b"['eligible', 'covid', 'vaccine', 'travel', 'work', 'thrilled', 'risk', 'vaccine', 'grateful', 'excite', 'covid', 'vaccine']\n"],
#  [1371842073712820226,
#   b"['good', 'covid', 'vaccine', 'new', 'tracking', 'vaccine', 'dose', 'time', 'frame', 'missed', 'dose', 'dose', 'interval']\n"],
#  [1352399350190768129,
#   b"['life or death', 'struggling', 'head', 'freedom', 'boom', 'privilege', 'poverty', 'tiny', 'jar', 'doubt', 'important', 'vaccine', 'covid']\n"],
#  [1366637158258204673,
#   b"['serious illness', 'vaccine', 'dose', 'show', 'fewer', 'symptomatic', 'covid', 'vaccine', 'drop', 'vaccine']\n"],
#  [1374331360194801664,
#   b"['work together', 'thank', 'health', 'continue', 'administer', 'available', 'covid', 'vaccine', 'vaccine', 'dose', 'covid', 'vaccine', 'update']\n"],
#  [1365306449757413387,
#   b"['health', 'approve', 'vaccine', 'covid', 'vaccine']\n"],
#  [1376140003219234817,
#   b"['thank', 'advocating', 'vaccine', 'priority', 'higher', 'risk', 'death', 'covid']\n"],
#  [1370196314403733512,
#   b"['redo', 'blot', 'super', 'grateful', 'angel', 'gear', 'vaccine']\n"],
#  [1369365118509793291,
#   b"['great', 'idea', 'folk', 'help', 'covid', 'vaccine', 'rollout', 'faster', 'better', 'vital', 'work', 'recognize', 'disadvantage', 'wage', 'disabled', 'childcare']\n"],
#  [1355510814862692355,
#   b"['first day', 'work together', 'packed lunch', 'work', 'marriage', 'vaccine', 'mum', 'vaccine', 'sad', 'make', 'vaccine']\n"],
#  [1366453668355203081,
#   b"['step closer', 'covid', 'vaccine', 'turn', 'normalcy', 'vaccine']\n"],
#  [1367571977985273856, b"['covid', 'push', 'vaccine', 'host', 'mask']\n"],
#  [1354134616643411968,
#   b"['mum', 'shares', 'reason', 'take', 'covid', 'vaccine']\n"],
#  [1374343759912177665,
#   b"['vaccine', 'upholding', 'oath', 'govern', 'revoke', 'ability', 'medicine', 'suspended', 'vaccine', 'experiment', 'covid']\n"],
#  [1353701668009906176,
#   b"['vaccine', 'protects', 'against', 'new', 'vaccine', 'against', 'variant', 'precaution']\n"],
#  [1376780631603081220,
#   b"['wait for', 'dose', 'notification', 'resend', 'important', 'dose', 'click', 'corona', 'vaccine', 'certificate', 'certificate', 'covid']\n"],
#  [1365632846753366017, b"['letters', 'end', 'sight', 'vaccine', 'covid']\n"],
#  [1366837954635730944,
#   b"['wait for', 'vaccine', 'safe', 'kids', 'little', 'worry', 'covid', 'vaccine']\n"],
#  [1370003750216032263, b"['adverse effect', 'vaccine', 'covid']\n"],
#  [1362072646968631300,
#   b"['adult', 'population', 'dose', 'vaccine', 'individual', 'priority', 'dose', 'vaccine', 'incredible', 'involve', 'vaccine', 'vaccine']\n"],
#  [1368065347841007617,
#   b"['back tomorrow', 'vaccine', 'medical', 'ally', 'discreet', 'sure', 'amazing', 'free', 'belt', 'wait', 'probable', 'vaccine']\n"],
#  [1350245738815524865, b"['vaccine', 'vaccine']\n"],
#  [1356878704090243074,
#   b"['frosty', 'calm', 'cork', 'judge', 'ferry', 'cork', 'covid', 'vaccine']\n"],
#  [1365577424231104513,
#   b"['expected', 'combatant', 'job', 'vaccine', 'work', 'home', 'vaccine']\n"],
#  [1357326286960623629,
#   b"['call', 'agree', 'pan', 'european', 'vaccine', 'certificate', 'example', 'say', 'duty', 'generate', 'turn', 'continue', 'covid']\n"],
#  [1349759602393575429,
#   b"['lag behind', 'important', 'vaccine', 'rollout', 'percent', 'vaccine']\n"],
#  [1344774065412706304,
#   b"['wish', 'happier', 'healthier', 'mask', 'vaccine', 'department']\n"],
#  [1376696268173549571,
#   b"['mental health', 'see through', 'abuse', 'vaccine', 'rollout', 'wholesale', 'afraid', 'gross', 'management', 'priority', 'inspire', 'confidence', 'vaccine', 'hell']\n"],
#  [1357645451982475271,
#   b"['covid', 'vaccine', 'rising', 'running', 'poll', 'vaccine', 'good', 'bad', 'neutral', 'positive', 'add', 'comment', 'covid', 'vaccine']\n"],
#  [1358069048215494656,
#   b"['pondering', 'imagine', 'vaccine', 'follow', 'recommended', 'guideline', 'folk', 'pandemic', 'vaccine', 'covid', 'vaccine']\n"],
#  [1362897986951479299,
#   b"['sunday', 'community', 'commitment', 'vaccine', 'access', 'better', 'vaccine', 'inequity', 'latest', 'covid', 'insight']\n"],
#  [1354050139070099468,
#   b"['getting ready', 'administer', 'retirement', 'covid', 'vaccine']\n"],
#  [1375523695087734787,
#   b"['time', 'urge', 'rabbit', 'headlight', 'quit', 'analysis', 'vaccine', 'coronavirus']\n"],
#  [1354443902300819459, b"['beautiful', 'vaccine', 'dose']\n"],
#  [1367040944260980739, b"['big', 'vaccine', 'rock', 'roll']\n"],
#  [1352359282029654016,
#   b"['redefine', 'ask', 'fight', 'against', 'covid', 'collectively', 'engage', 'refocus', 'community', 'debt', 'forgiveness', 'space', 'vaccine', 'better']\n"],
#  [1352572411980427266,
#   b"['covid', 'pandemic', 'control', 'addition', 'widespread', 'distribution', 'vaccine', 'priority']\n"],
#  [1372987971939540997,
#   b"['advantage', 'certa', 'vintage', 'honestly', 'cry', 'vaccine', 'covid']\n"],
#  [1372636054377873419, b"['huge', 'wow', 'thank', 'involve', 'vaccine']\n"],
#  [1346370842221953024,
#   b"['worry', 'regard', 'vaccine', 'initially', 'priority', 'vaccine', 'production', 'ensure', 'late', 'supplied', 'deal']\n"],
#  [1352271199968120835,
#   b"['dose', 'covid', 'vaccine', 'allergic', 'upset', 'swab', 'positive', 'covid']\n"],
#  [1356211544334471168,
#   b"['understand', 'community', 'concerned', 'hosting', 'free', 'panel', 'answer', 'hear', 'founder', 'lord', 'wolley', 'vaccine']\n"],
#  [1365217758133293057, b"['hurt', 'urge', 'turn', 'royal', 'vaccine']\n"],
#  [1364519587933544448,
#   b"['survivor', 'lost', 'desperate', 'offer', 'help', 'payback', 'bargain', 'fancy', 'vaccine']\n"],
#  [1350586128877973509,
#   b"['ask', 'vaccine', 'dose', 'develop', 'immunity', 'corona']\n"],
#  [1364647429446934530,
#   b"['wear', 'mask', 'social', 'distance', 'wash', 'covid', 'vaccine', 'reality', 'covid', 'hoax', 'death']\n"],
#  [1376228469672132611, b"['vaccine', 'vaccine']\n"],
#  [1346519947095240704,
#   b"['firefighter', 'vaccine', 'negotiation', 'range', 'vaccine', 'booster', 'absurd', 'covid']\n"],
#  [1371604644431036416,
#   b"['covid', 'vaccine', 'clot', 'vaccine', 'myth', 'look', 'clot', 'occur', 'higher', 'vaccine']\n"],
#  [1374549812826284032,
#   b"['science', 'amazing', 'incredible', 'blessed', 'dose', 'vaccine']\n"],
#  [1361695047104741376,
#   b"['spying on', 'hacker', 'covid', 'vaccine', 'pharmaceutical', 'claim', 'covid', 'frantically', 'stealing', 'info']\n"],
#  [1346572155308355591,
#   b"['pure joy', 'call', 'care', 'closest', 'relate', 'live', 'ask', 'consented', 'covid', 'vaccine', 'sunday', 'hesitation', 'pandemic']\n"],
#  [1357328506670227457,
#   b"['happy', 'vaccine', 'live', 'luck', 'efficient', 'appointment', 'scheduled', 'time', 'hilly', 'vaccine', 'covid']\n"],
#  [1365793072806825988,
#   b"['made up', 'certainly', 'epidemiologist', 'vaccine', 'push', 'full', 'crap']\n"],
#  [1371761265903874052,
#   b"['uniquely', 'vaccine', 'cost', 'seek', 'profiteer', 'pandemic']\n"],
#  [1373011589310382089,
#   b"['vulnerable population', 'covid', 'vaccine', 'encourage', 'covid', 'vaccine', 'turn', 'helps', 'protect', 'love', 'community', 'live', 'serve', 'covid', 'vaccine']\n"],
#  [1355154437229187075,
#   b"['worker', 'vaccine', 'risk', 'cancer', 'patient', 'impatiently', 'home']\n"],
#  [1346899186420232203,
#   b"['covid', 'love', 'yummy', 'nuts', 'protected', 'vaccine']\n"],
#  [1374153618845274115,
#   b"['conversations about', 'labour party', 'covid', 'vaccine', 'leader', 'holborn', 'healthcare', 'volunteer', 'instrumental', 'nationwide', 'vaccine', 'rollout', 'vaccine', 'covid']\n"],
#  [1358065017162240000,
#   b"['covid', 'ensuring', 'efficacy', 'prevent', 'abscond', 'reopen', 'fantastic', 'service', 'vaccine']\n"],
#  [1371694427836612618,
#   b"['loue', 'famously', 'father', 'vaccine', 'cholera', 'discover', 'causal', 'bacteria', 'lost', 'infective', 'nature', 'time', 'vaccine']\n"],
#  [1362317233003720704,
#   b"['mood', 'contained', 'fury', 'govern', 'acknowledge', 'high', 'connected', 'vip', 'jumped', 'vaccine', 'queue', 'vaccine']\n"],
#  [1348677201068232705,
#   b"['hang on', 'covid', 'vaccine', 'kids', 'sure', 'badger', 'stop', 'catching', 'cattle']\n"],
#  [1356934720463007747,
#   b"['vaccine', 'against', 'covid', 'vaccine', 'vaccine', 'coronavirus']\n"],
#  [1348668817912819719,
#   b"['step in', 'ternate', 'community', 'extreme', 'pressure', 'regime', 'accept', 'independent', 'regime', 'response', 'crisis', 'vaccine']\n"],
#  [1352292681058279424,
#   b"['vaccine', 'healthcare', 'economic', 'social', 'crisis', 'created', 'covid', 'trudeau', 'understands', 'vaccine']\n"],
#  [1376562294705033218,
#   b"['blame', 'eurozone', 'weakness', 'slow', 'vaccine', 'rollout', 'partially', 'true', 'factor', 'detached', 'main', 'reason', 'massive', 'bureaucracy']\n"],
#  [1369031082755100675,
#   b"['best', 'vaccine', 'approved', 'available', 'vaccine', 'covid']\n"],
#  [1362888752767590403,
#   b"['cent', 'vaccine', 'fast', 'efficient', 'capacity', 'dose', 'process', 'covid', 'coronavirus']\n"],
#  [1357643600683802625,
#   b"['evil conspiracy', 'vaccine', 'theorist', 'predict', 'last', 'vaccine']\n"],
#  [1355230577113362434,
#   b"['i like', 'too much', 'involve', 'wanted', 'acknowledge', 'amazing', 'wonderful', 'job', 'vaccine', 'bringing', 'goodwill', 'love', 'vaccine']\n"],
#  [1356597164126969857,
#   b"['full', 'friendly', 'efficient', 'volunteer', 'green', 'health', 'covid', 'vaccine']\n"],
#  [1374363226746535941,
#   b"['medical', 'administration', 'approved', 'clinical', 'trial', 'covid', 'vaccine', 'domestic', 'institute', 'medicine', 'science']\n"],
#  [1354502427794427906,
#   b"['serum', 'institute', 'income', 'vaccine', 'receiving', 'dollar', 'investment', 'funding']\n"],
#  [1365143185719242757,
#   b"['big sigh', 'aunt', 'vaccine', 'drive', 'vaccine']\n"],
#  [1359384674276175872,
#   b"['healthcare professional', 'family', 'wonderful', 'family', 'group', 'capt', 'giving', 'hope', 'vaccine', 'vaccine', 'covid']\n"],
#  [1354139724596785152,
#   b"['peer review', 'test positive', 'vaccine', 'older', 'covid', 'vaccine', 'preliminary', 'vaccine', 'show', 'compare']\n"],
#  [1374036764235472896,
#   b"['miss family', 'scheduled', 'vaccine', 'dose', 'dent', 'friends', 'vaccine']\n"],
#  [1362099737600659456,
#   b"['ready to', 'vaccine', 'work', 'hospital', 'transport', 'support', 'service', 'home', 'hospital', 'vaccine', 'helps', 'protect', 'community', 'vaccine', 'vaccine']\n"],
#  [1370771000707719168,
#   b"['covid', 'covid', 'coronavirus', 'vaccine', 'vaccine', 'political', 'gallery']\n"],
#  [1351208779300417565,
#   b"['know how', 'speed dial', 'houre', 'vaccine', 'moth', 'call', 'dose', 'available', 'hospital', 'advocate', 'confusion', 'pipeline', 'covid', 'vaccine']\n"],
#  [1357027028508303361,
#   b"['i want', 'know', 'offer', 'vaccine', 'meane', 'chance', 'meane', 'injection', 'injection', 'ask', 'injection', 'vaccine']\n"],
#  [1346467779587633153,
#   b"['strongly', 'encouraging', 'working', 'patient', 'roles', 'offer', 'covid', 'vaccine', 'take', 'updated', 'advice', 'light', 'vaccine', 'covid', 'vaccine']\n"],
#  [1361336970484580358,
#   b"['batch', 'dose', 'covid', 'vaccine', 'capital', 'aid', 'airport']\n"],
#  [1353735687917477888,
#   b"['time', 'scandal', 'involve', 'funds', 'drop', 'remember', 'money', 'covid', 'vaccine']\n"],
#  [1366348705830371334, b"['vaccine', 'comorbid', 'vaccine']\n"],
#  [1367919501329711104,
#   b"['ready to', 'dose', 'vaccine', 'wear', 'homage', 'pure', 'love', 'amazing', 'vaccine', 'quickly', 'vaccine']\n"],
#  [1347612941554749445,
#   b"['way out', 'forced', 'tighten', 'measure', 'beating', 'vaccine', 'drive', 'fool', 'vaccine', 'dream', 'covid', 'vaccine', 'covid', 'covid']\n"],
#  [1366922669245927426, b"['heart', 'singing', 'vaccine']\n"],
#  [1355216816382087169, b"['charmed', 'vaccine']\n"],
#  [1354942374183579648,
#   b"['birthday present', 'sore arm', 'work', 'colleague', 'working', 'vaccine', 'dose', 'covid', 'inoculation', 'wonderful', 'early', 'vaccine', 'covid']\n"],
#  [1374782144745181193,
#   b"['early on', 'targets', 'scorecards', 'predictions', 'dose', 'take', 'average', 'growing', 'dose', 'debt', 'vaccine']\n"],
#  [1357394345410895873,
#   b"['lies in', 'euro', 'vaccine', 'working', 'against', 'help', 'realize', 'quickly', 'solution', 'problem', 'jew', 'carry', 'method', 'correct', 'vaccine']\n"],
#  [1353330957311496192,
#   b"['new', 'ternate', 'dose', 'slow', 'vaccine', 'covid', 'dose', 'coronavirus', 'vaccine', 'push', 'compare']\n"],
#  [1357787028234985472,
#   b"['rolling stone', 'old', 'dodger', 'last', 'vaccine']\n"],
#  [1352149234376704003,
#   b"['tinfoil', 'hat', 'deny', 'remember', 'say', 'covid', 'hoax', 'know', 'died', 'saying', 'moat', 'coronavirus', 'vaccine']\n"],
#  [1354954564391362567,
#   b"['covid', 'vaccine', 'vaccine', 'update', 'dose', 'last', 'update', 'top', 'gains', 'bottom', 'dropped']\n"],
#  [1364965123203489796,
#   b"['ready to', 'carry out', 'continue', 'provide', 'support', 'capacity', 'combat', 'covid', 'vaccine', 'cooperation', 'call']\n"],
#  [1372603707389448192,
#   b"['blood clot', 'medicine', 'regulator', 'benefits', 'covid', 'vaccine', 'exceed', 'potential', 'rare', 'brain']\n"],
#  [1355513716289265664,
#   b"['real', 'response', 'vaccine', 'embodiment', 'joke', 'jewish', 'kosher', 'restaurant', 'call', 'wait', 'food', 'disgusting', 'inedible', 'chime', 'portion']\n"],
#  [1366309159218610179,
#   b"['comment', 'vaccine', 'diplomacy', 'pandemic', 'security', 'management', 'regime', 'stability', 'regional', 'influence']\n"],
#  [1351880654133354498,
#   b"['die', 'testing', 'positive', 'covid', 'covid', 'death', 'die', 'vaccine', 'die', 'covid', 'covid', 'vaccine']\n"],
#  [1366748011360100361,
#   b"['ranked among', 'remain', 'open', 'position', 'safest', 'effective', 'test', 'trace', 'programmes', 'top', 'nations', 'vaccine', 'rollout']\n"],
#  [1358926291135655936, b"['offer', 'take', 'vaccine']\n"],
#  [1376780315423875074,
#   b"['believe', 'proof', 'crow', 'support', 'proof', 'house', 'endorses', 'vaccine', 'segregation', 'segregation', 'segregation', 'forever', 'oppose']\n"],
#  [1350048539502645249,
#   b"['moral obligation', 'big chunk', 'population', 'vaccine', 'conveniently', 'forget', 'population', 'look', 'covid', 'vaccine']\n"],
#  [1371096759347347460,
#   b"['sticker', 'relief', 'sacrifice', 'last', 'worth', 'thank', 'vaccine']\n"],
#  [1358149421842718720, b"['thank', 'loving', 'new', 'sticker', 'vaccine']\n"],
#  [1365343387524726784,
#   b"['bright', 'early', 'covid', 'vaccine', 'vaccine']\n"],
#  [1374380439859695622,
#   b"['supplied', 'vaccine', 'dose', 'vaccine', 'supplied', 'clear', 'improve', 'rollout', 'vaccine', 'vaccine']\n"],
#  [1354649100948545536,
#   b"['vaccine', 'supplies', 'key', 'partner', 'dose', 'vaccine']\n"],
#  [1354760847160176642,
#   b"['vaccine', 'vaccine', 'vaccine', 'vaccine', 'vaccine']\n"],
#  [1367995394802683904,
#   b"['infectious disease', 'hospital', 'specialist', 'shrine', 'new', 'vaccine', 'good', 'vaccine', 'faster', 'vaccine', 'faster', 'pandemic']\n"],
#  [1355945194227724293, b"['possible', 'corona', 'vaccine', 'vaccine']\n"],
#  [1356321835751796736,
#   b"['perpetuate', 'lie', 'vaccine', 'offer', 'vaccine', 'undermine', 'vaccine', 'rollout', 'false']\n"],
#  [1367068043197640708,
#   b"['visited', 'health', 'officer', 'discuss', 'vaccine', 'administration']\n"],
#  [1347547533510373377,
#   b"['full time', 'lucky', 'employment', 'aware', 'struggling', 'fight', 'normal', 'vaccine', 'best', 'vaccine']\n"],
#  [1360964629023891458,
#   b"['health issue', 'younger', 'cheating', 'affluent', 'population', 'vaccine', 'top', 'vaccine']\n"],
#  [1372201025797558278,
#   b"['appointment', 'vaccine', 'hope', 'fast', 'appointment', 'houre', 'shake', 'anxiety', 'vaccine']\n"],
#  [1345792094758182913,
#   b"['stocking', 'covid', 'subside', 'love', 'connect', 'scheduled', 'receive', 'vaccine', 'baby', 'autograph', 'vaccine']\n"],
#  [1373551410663452674,
#   b"['effective', 'severity', 'covid', 'lifestyle', 'health', 'light', 'exercise', 'alcohol', 'vaccine', 'meaningful', 'certainly', 'tick']\n"],
#  [1359853498549084163,
#   b"['join on', 'live', 'work', 'unsure', 'vaccine', 'ask', 'medical', 'full', 'detail']\n"],
#  [1357986123868491778,
#   b"['potential', 'saving', 'reflective', 'mood', 'reckon', 'ask', 'stranger', 'direction', 'sec', 'pin', 'accuracy', 'louisa', 'whit', 'idea', 'vaccine']\n"],
#  [1363111031497719811,
#   b"['interesting', 'released', 'covid', 'vaccine', 'nice', 'loyalist', 'deference', 'seal', 'curious', 'partisan', 'defensive', 'immigrants', 'undemocratic']\n"],
#  [1371920543386103810, b"['i like', 'time', 'vaccine', 'happy', 'vaccine']\n"],
#  [1371950966988099585,
#   b"['clear', 'experiment', 'vaccine', 'gamble', 'serious', 'effects', 'death', 'stroke', 'covid', 'vaccine']\n"],
#  [1372053090497536002,
#   b"['beware', 'testing', 'positive', 'covid', 'dose', 'vaccine', 'ugly', 'coronavirus']\n"],
#  [1364529097112621056,
#   b"['govern', 'provide', 'vaccine', 'free', 'cost', 'write', 'ask', 'alert', 'authority', 'purchase', 'vaccine']\n"],
#  [1349664829334827008,
#   b"['urgent', 'full', 'transparency', 'real', 'stag', 'negotiation', 'transparency', 'vaccine']\n"],
#  [1370406252300341250,
#   b"['health care', 'to do', 'pharmacy', 'convenient', 'covid', 'vaccine', 'access', 'participant', 'federal', 'pharmacy', 'show', 'success', 'vital', 'professional', 'community']\n"],
#  [1351449224798482432,
#   b"['helpful', 'hear', 'vaccine', 'hesitant', 'language']\n"],
#  [1347982833982320640,
#   b"['looking forward', 'depends on', 'covid', 'vaccine', 'clinic', 'great', 'job', 'ramp', 'capacity', 'give', 'vaccine', 'success', 'vaccine', 'supply', 'vaccine']\n"],
#  [1349856576648011778, b"['festival', 'convention', 'covid', 'vaccine']\n"],
#  [1346008632794738688,
#   b"['last minute', 'prepare', 'roll', 'vaccine', 'fag', 'panic']\n"],
#  [1373415483605708809,
#   b"['focus on', 'social activity', 'true', 'worry', 'mask', 'restricting', 'play', 'avoiding', 'high', 'effective', 'vaccine', 'mutant']\n"],
#  [1351785602924990465,
#   b"['covid', 'vaccine', 'shipment', 'gift', 'govern', 'covid', 'coronavirus', 'vaccine', 'vaccine']\n"],
#  [1345867490820165633, b"['ambitious']\n"],
#  [1349449399013957636,
#   b"['covid', 'vaccine', 'little', 'ouch', 'sign', 'chat', 'immune', 'system', 'humble', 'grateful', 'medical', 'miracle', 'family', 'huge', 'thanks']\n"],
#  [1371774493681721346,
#   b"['blood clot', 'pain', 'announced', 'halt', 'rollout', 'vaccine', 'fear', 'medicine', 'insist', 'safe']\n"],
#  [1345999371113009157,
#   b"['lesson', 'bigger', 'vaccine', 'hope', 'move', 'differently', 'kick', 'vaccine', 'important', 'humane', 'better', 'vaccine']\n"],
#  [1348427616106262528,
#   b"['wait for', 'consequence', 'vaccine', 'nightmare', 'folk', 'travelling', 'vaccine']\n"],
#  [1350061451881418753,
#   b"['well done', 'support', 'covid', 'vaccine', 'involve', 'ensure', 'process', 'safely', 'great', 'success', 'vaccine', 'covid']\n"],
#  [1349048501146103813,
#   b"['ask', 'release', 'vaccine', 'dose', 'covid', 'stead', 'holding', 'implement', 'strategy', 'dose', 'reserve', 'guard', 'potential', 'issues']\n"],
#  [1348079309999775746,
#   b"['covid', 'vaccine', 'airborne', 'virus', 'vaccine', 'massive', 'response', 'vaccine', 'call']\n"],
#  [1349634045945257986,
#   b"['amazing', 'covid', 'vaccine', 'dose', 'dose', 'available', 'addition', 'target', 'dose']\n"],
#  [1349350324075712518,
#   b"['good news', 'vaccine', 'turn', 'vaccine', 'take', 'slack', 'system']\n"],
#  [1356908904249241600,
#   b"['renew', 'commitment', 'advocating', 'vaccine', 'prevent', 'vaccine']\n"],
#  [1353379107761885186,
#   b"['covid', 'updated', 'sunday', 'new', 'death', 'within', 'positive', 'test', 'report', 'tote', 'dose', 'vaccine']\n"],
#  [1355585822158970882,
#   b"['join on', 'live', 'covid', 'conversation', 'brilliant', 'vaccine', 'covid']\n"],
#  [1354931043502067725,
#   b"['proud', 'giving', 'vaccine', 'special', 'contained', 'teach', 'calm', 'reassuring', 'helped', 'covid', 'vaccine']\n"],
#  [1365558160170356737, b"['old', 'time', 'vaccine', 'training']\n"],
#  [1359937765492809731,
#   b"['good news', 'against', 'covid', 'approve', 'vaccine', 'emergency', 'vaccine', 'research', 'vector', 'vaccine', 'phase', 'trial', 'journal']\n"],
#  [1373424176241999874,
#   b"['vaccine', 'wear', 'mask', 'guidance', 'vaccine']\n"],
#  [1363160454072332291,
#   b"['stay tuned', 'early on', 'targets', 'scorecards', 'dose', 'average', 'target', 'scorecards', 'updated', 'weekend', 'vaccine']\n"],
#  [1352598589726470145, b"['catching', 'space', 'vaccine']\n"],
#  [1354544466263224324,
#   b"['great', 'new', 'new', 'vaccine', 'against', 'safe', 'effective', 'pregnant', 'research', 'via']\n"],
#  [1371549857891164165,
#   b"['causal link', 'suspension', 'vaccine', 'european', 'monstrous', 'mistake', 'clot', 'vaccine', 'suspension', 'certa', 'cause', 'death', 'prevent', 'covid']\n"],
#  [1356561182904119299,
#   b"['flu symptom', 'all in', 'vaccine', 'work', 'poorly', 'sick', 'great', 'hope', 'arse']\n"],
#  [1345136254535540738,
#   b"['good', 'game', 'turn', 'roll', 'take', 'experiment', 'approved', 'vaccine', 'virus', 'against', 'excellent', 'covid']\n"],
#  [1348552435657179141,
#   b"['gas', 'tragedy', 'victim', 'death', 'participate', 'clinical', 'trial', 'unrelated', 'vaccine', 'open', 'pandora', 'ethic', 'legal', 'issues', 'clinical', 'trial', 'covid', 'vaccine']\n"],
#  [1376552473498947588,
#   b"['trade', 'vaccine', 'vaccine', 'alone', 'needed', 'reality', 'check', 'check', 'covid', 'vaccine', 'challenge']\n"],
#  [1363474433999056901,
#   b"['example', 'vaccine', 'late', 'cause', 'infertility', 'reason', 'covid', 'vaccine', 'know']\n"],
#  [1360406838928412672,
#   b"['sore arm', 'fatigue', 'muscle', 'ache', 'fever', 'covid', 'vaccine', 'celebrated', 'happy', 'covid', 'vaccine', 'vaccine', 'covid']\n"],
#  [1355087625330241537,
#   b"['in depth', 'update', 'covid', 'vaccine', 'continue', 'reduce', 'travel', 'wear', 'mask', 'stay', 'home', 'info', 'available', 'covid', 'vaccine']\n"],
#  [1372237281172553733,
#   b"['remind of', 'too small', 'fathom', 'attitude', 'vaccine', 'reluctant', 'oldie', 'resort', 'food', 'terrible', 'portion']\n"],
#  [1359408528058908674,
#   b"['to watch', 'take', 'short', 'leader', 'importance', 'covid', 'vaccine']\n"],
#  [1361315343575224320,
#   b"['promising new', 'take', 'study', 'drop', 'symptomatic', 'covid', 'vaccine', 'reuter', 'covid', 'vaccine']\n"],
#  [1350106413272424448,
#   b"['deep', 'know', 'examination', 'bad', 'vaccine', 'vaccine']\n"],
#  [1364615594230833153,
#   b"['presser', 'promise', 'deliver', 'new', 'dose', 'covid', 'vaccine', 'end', 'vax', 'approved', 'bringing', 'board']\n"],
#  [1373082942759657473, b"['bad idea', 'vaccine', 'covid']\n"],
#  [1344971818428489733,
#   b"['coronavirus', 'vaccine', 'approved', 'emergency', 'health', 'organise', 'meane', 'available', 'poorer', 'nations', 'dose', 'worldwide', 'covid', 'vaccine']\n"],
#  [1348701170756423681,
#   b"['coordinating committee', 'include', 'govern', 'department', 'stakeholder', 'community', 'oversee', 'distribution', 'vaccine', 'vaccine']\n"],
#  [1372852828918648835,
#   b"['late', 'distribute', 'calculations', 'fewer', 'vaccine', 'cautious', 'delay', 'show', 'erosion', 'confidence', 'vaccine', 'rollout', 'coronavirus']\n"],
#  [1353197126503677953, b"['exclusive', 'illustrate', 'vaccine']\n"],
#  [1346918232750485505,
#   b"['good', 'gab', 'emergency', 'physician', 'comment', 'vaccine', 'protect', 'family', 'care', 'help', 'curb', 'covid']\n"],
#  [1371505632885497860,
#   b"['patient', 'scheduled', 'last', 'covid', 'vaccine', 'sister', 'care', 'patient', 'hesitant', 'vaccine']\n"],
#  [1350317091006554114,
#   b"['rocks', 'political', 'testimony', 'talent', 'skill', 'normal', 'make', 'vaccine', 'short', 'time', 'vaccine', 'ready']\n"],
#  [1373887066262663170,
#   b"['good morning', 'closer', 'golf', 'hospital', 'training', 'good', 'vaccine', 'vaccine']\n"],
#  [1365059721141628933, b"['last', 'vaccine', 'vaccine']\n"],
#  [1345359186499047424,
#   b"['advantage', 'approved', 'covid', 'vaccine', 'vaccine', 'safe', 'vaccine', 'free', 'check', 'answer']\n"],
#  [1348534130879901696,
#   b"['highest', 'vaccine', 'acceptance', 'approval', 'govern', 'coronavirus', 'pandemic']\n"],
#  [1354288283963035649,
#   b"['pleased', 'work', 'colleague', 'new', 'study', 'reduce', 'covid', 'vaccine', 'hesitancy', 'incarcerated', 'critical', 'timely', 'research']\n"],
#  [1357287020717109251,
#   b"['great', 'vaccine', 'raising', 'alarm', 'vaccine', 'supply', 'cooperation', 'yes', 'predictable', 'unethical']\n"],
#  [1346211940989890560,
#   b"['approve', 'covid', 'vaccine', 'reassuring', 'vaccine', 'dose', 'together']\n"],
#  [1358336076881010696,
#   b"['community', 'vaccine', 'refused', 'vaccine', 'confidence', 'vaccine', 'mistrust', 'mistrust', 'misinformation']\n"],
#  [1366302180706254848,
#   b"['covid', 'vaccine', 'catch', 'full', 'report', 'important', 'fight', 'virus']\n"],
#  [1352772782963220485,
#   b"['covid', 'vaccine', 'updated', 'vaccine', 'graph', 'true', 'estimate', 'population', 'dose', 'cape', 'reached', 'population', 'dose']\n"],
#  [1363705711054622726,
#   b"['covid', 'vaccine', 'probable', 'trending', 'persecute', 'hate']\n"],
#  [1374079709898698755,
#   b"['step closer', 'vaccine', 'yay', 'covid', 'thanks', 'vaccine', 'help', 'stop', 'spread', 'covid']\n"],
#  [1370397332274089991,
#   b"['friday night', 'remember', 'excite', 'bar', 'vaccine']\n"],
#  [1366164739286573058,
#   b"['sprinter', 'prefer', 'olympic', 'take', 'covid', 'vaccine', 'vaccine']\n"],
#  [1349984809439911941,
#   b"['fake news', 'community', 'uptake', 'causing', 'minority', 'reject', 'covid']\n"],
#  [1364582877195870211,
#   b"['dataset', 'present', 'vaccine', 'efficacy', 'diminished', 'covid', 'small', 'effective']\n"],
#  [1351202203856490498, b"['dose', 'covid', 'vaccine']\n"],
#  [1358726616273145858,
#   b"['on heels', 'trudeau', 'call', 'covid', 'vaccine', 'infection', 'vaccine']\n"],
#  [1359875028712628231,
#   b"['see', 'rank', 'share', 'covid', 'impact', 'family', 'priority', 'vaccine']\n"],
#  [1355580806245326848,
#   b"['via', 'butt', 'myth', 'turn', 'take', 'vaccine', 'beat', 'covid']\n"],
#  [1351667005980610563,
#   b"['higher', 'appear', 'batch', 'vaccine', 'community', 'clinic', 'prompt', 'health', 'department', 'ask', 'clinic', 'stop', 'dose', 'batch', 'vaccine']\n"],
#  [1370002573579714560,
#   b"['put o', 'dose', 'permanent', 'tattoo', 'ok', 'cool', 'design', 'show', 'vaccine']\n"],
#  [1365241927893942273,
#   b"['good friend', 'on behalf', 'delighted', 'coleman', 'interviewed', 'consultant', 'offers', 'perspective', 'vaccine', 'covid']\n"],
#  [1354489274020855809,
#   b"['health risk', 'close', 'mate', 'plus', 'beat', 'mid', 'target', 'vaccine']\n"],
#  [1347991113337098240, b"['queue', 'vaccine', 'die', 'deadly']\n"],
#  [1349128366767689731,
#   b"['join', 'scheme', 'join', 'vaccine', 'scheme', 'vaccine', 'catastrophic', 'scheme', 'ideological', 'vaccine']\n"],
#  [1351151682462359555,
#   b"['see', 'double', 'covid', 'vaccine', 'fighting', 'fit', 'look', 'favourite', 'family', 'featuring', 'fearsome', 'aussie', 'hound']\n"],
#  [1358217031477194752, b"['old', 'dose', 'vaccine', 'relieved']\n"],
#  [1356281566264131585,
#   b"['working closely', 'healthcare', 'brief', 'assist', 'health', 'new', 'vaccine', 'safety', 'provide', 'safe', 'environment', 'appointments', 'covid', 'vaccine']\n"],
#  [1346159784630824960,
#   b"['early on', 'gained', 'head', 'supplies', 'vaccine']\n"],
#  [1371572978211827719,
#   b"['suspend', 'vaccine', 'rollout', 'safety', 'concern', 'safe', 'vaccine', 'come', 'freedom', 'covid', 'vaccine', 'freedom', 'wakeup']\n"],
#  [1371525575664414724,
#   b"['blood clot', 'halt', 'rollout', 'vaccine', 'incidents', 'involve', 'unite', 'kingdom', 'suspend', 'vaccine', 'vaccine', 'coronavirus']\n"],
#  [1369677524561707010,
#   b"['covid', 'dose', 'covid', 'werewolf', 'transformation', 'vaccine', 'lycanthrope']\n"],
#  [1350056399158571008,
#   b"['cathedral', 'receive', 'coronavirus', 'vaccine', 'king', 'see', 'vaccine', 'covid']\n"],
#  [1361639259598426114, b"['flat', 'covid', 'vaccine', 'batter', 'vaccine']\n"],
#  [1363850163480104962,
#   b"['up for', 'touches', 'concern', 'failure', 'include', 'priority', 'covid', 'vaccine']\n"],
#  [1361348335261650945,
#   b"['miss family', 'wait to see', 'covid', 'vaccine', 'protect', 'model', 'lead', 'example', 'come', 'protected', 'vaccine']\n"],
#  [1352022570170785792,
#   b"['vaccine', 'good', 'vaccine', 'vaccine', 'covid', 'inauguration', 'inauguration', 'inauguration']\n"],
#  [1347667381066354694,
#   b"['well done', 'super', 'resource', 'involve', 'education', 'vaccine']\n"],
#  [1367656453780238339,
#   b"['pleasure', 'vaccine', 'thank', 'farm', 'choose', 'local', 'independent', 'pharmacy', 'administer', 'vaccine', 'covid', 'vaccine']\n"],
#  [1362872866975346689,
#   b"['negatively impact', 'break down', 'flood', 'estimated', 'mask', 'mask', 'take', 'slowly', 'plastic', 'marine', 'wildlife', 'ecosystem', 'covid', 'vaccine']\n"],
#  [1356640517044506625,
#   b"['early on', 'b day', 'ahead of time', 'targets', 'scorecards', 'dose', 'average', 'targets', 'predict', 'achieve', 'vaccine']\n"],
#  [1358300371807051777,
#   b"['ready to', 'container', 'covid', 'vaccine', 'liberation', 'army', 'take', 'request', 'army', 'army', 'receive', 'vaccine', 'aid']\n"],
#  [1345928586788802560,
#   b"['covid', 'vaccine', 'big', 'milestone', 'approval', 'give', 'vaccine', 'approval', 'phase', 'trial']\n"],
#  [1357056232159330308,
#   b"['old', 'rose', 'covid', 'vaccine', 'old', 'daughter']\n"],
#  [1349486981202366465,
#   b"['thank', 'vaccine', 'efficient', 'easy', 'dare', 'say', 'joy', 'vaccine']\n"],
#  [1363116021457051650,
#   b"['joyful', 'stop', 'community', 'vaccine', 'clinic', 'early', 'partnership', 'reaching', 'together', 'make', 'sure', 'access', 'vaccine']\n"],
#  [1374413089861378052,
#   b"['stub', 'rolled', 'dose', 'covid', 'vaccine', 'clinic', 'responder', 'covid', 'vaccine']\n"],
#  [1349486586849800193, b"['vaccine', 'excite', 'covid', 'vaccine']\n"],
#  [1353704438163243010,
#   b"['covid', 'vaccine', 'supporting', 'equitable', 'access', 'vaccine']\n"],
#  [1351616090573565952, b"['grateful', 'coronavirus', 'vaccine']\n"],
#  [1359951795716411392,
#   b"['clinic', 'convention', 'cent', 'covid', 'coronavirus', 'covid', 'vaccine']\n"],
#  [1367255969713942536,
#   b"['late for', 'dose', 'vaccine', 'little', 'concern', 'govern', 'manufacture']\n"],
#  [1367814306834878466,
#   b"['up to date', 'discuss', 'research', 'collaboration', 'helps', 'stay', 'covid', 'vaccine', 'development']\n"],
#  [1357858033733226496,
#   b"['vaccine', 'sunday', 'shipment', 'beg', 'vaccine', 'scheduled']\n"],
#  [1375389294286794752,
#   b"['grow pair', 'deal with', 'angry', 'sanction', 'vaccine']\n"],
#  [1369623657048334338,
# ...
#   b"['volunteer', 'spirit', 'full', 'display', 'massive', 'vaccine', 'vaccine']\n"],
#  [1367123327186317318,
#   b"['perfectly fine', 'dose', 'vaccine', 'together', 'walking', 'vaccine', 'vaccine']\n"],
#  [1358125924898594821,
#   b"['community outreach', 'take advantage', 'waste time', 'lull', 'covid', 'vaccine', 'shipment']\n"],
#  [1354363750409789441,
#   b"['nobody', 'giving', 'social', 'distance', 'positive', 'vaccine']\n"],
#  [1347194725342666755,
#   b"['share', 'tip', 'loved', 'together', 'vaccine', 'conscience', 'covid']\n"],
#  [1373340330112774145,
#   b"['biggest challenge', 'embarking on', 'high resistance', 'ambitious', 'health', 'outreach', 'vaccine', 'achieve', 'herd', 'immunity', 'within', 'vaccine']\n"],
#  [1375927419635445765,
#   b"['ask for', 'mama', 'recieve', 'dose', 'covid', 'vaccine', 'phew', 'call', 'update', 'haha', 'vaccine', 'covid']\n"],
#  [1365272217366507522,
#   b"['authors suggest', 'correspondence', 'early', 'covid', 'infection', 'compare', 'immune', 'serology', 'test', 'vaccine', 'dose', 'prioritise', 'individual', 'dose']\n"],
#  [1361273725077757954,
#   b"['vaccine', 'vaccine', 'ignore', 'dark', 'circles']\n"],
#  [1355629878444490754,
#   b"['late for', 'vaccine', 'roll', 'vaccine', 'suddenly', 'vax', 'trail', 'offer', 'mix', 'vaccine']\n"],
#  [1353738394107576321,
#   b"['drop', 'hospital', 'admission', 'death', 'falling', 'vaccine', 'bite', 'younger', 'ease']\n"],
#  [1363852587519389697,
#   b"['demonstrate', 'pigheaded', 'ignorance', 'playing', 'vaccine', 'covid', 'rising', 'sneer', 'effective', 'vaccine']\n"],
#  [1345412811384565761, b"['vaccine', 'zoom']\n"],
#  [1351274602505256962,
#   b"['no count', 'allergic reaction', 'update', 'vaccine', 'investigate', 'possible', 'halt', 'dose', 'receive', 'dose', 'covid', 'coronavirus']\n"],
#  [1344760239535628297,
#   b"['health', 'organization', 'emergency', 'coronavirus', 'vaccine', 'kinde', 'receive', 'emergency', 'validation', 'covid', 'outbreak']\n"],
#  [1360350357486993411,
#   b"['old', 'niece', 'impaired', 'respiratory', 'function', 'darling', 'cheeky', 'madam', 'problems', 'vaccine']\n"],
#  [1373203557273497600,
#   b"['superhero', 'medicine', 'born', 'discover', 'vaccine', 'cholera', 'plague', 'saving', 'live', 'vaccine', 'cholera', 'medicine']\n"],
#  [1369240705890189314,
#   b"['hospital', 'infection', 'vaccine', 'checked', 'late']\n"],
#  [1375745631986257921,
#   b"['panel discussion', 'join on', 'glad', 'host', 'access', 'covid', 'vaccine', 'misinformation', 'discussion', 'eat', 'zoom', 'link', 'vaccine']\n"],
#  [1348000441871847426,
#   b"['amazing', 'vaccine', 'capacity', 'weekend', 'accommodate', 'vaccine']\n"],
#  [1347483209278382080,
#   b"['ask', 'detail', 'prove', 'identity', 'arrive', 'announced', 'home', 'administer', 'vaccine', 'protect', 'covid']\n"],
#  [1348656667127410689,
#   b"['quoting', 'document', 'vaccine', 'system', 'functionality', 'support', 'vaccine', 'rollout']\n"],
#  [1348868044970459137,
#   b"['vaccine', 'rollout', 'strategy', 'support', 'remember', 'last', 'kids', 'midst', 'shutdown', 'covid', 'violence', 'targets', 'job']\n"],
#  [1345610429226106880,
#   b"['good news', 'new beginning', 'new', 'emergency', 'approval', 'corona', 'vaccine']\n"],
#  [1375810528715579396,
#   b"['vaccine', 'cooperation', 'receives', 'batch', 'dose', 'covid', 'vaccine']\n"],
#  [1358797759709601795,
#   b"['roll', 'vaccine', 'grow', 'head', 'works', 'vaccine']\n"],
#  [1351888790680461315,
#   b"['birthday present', 'mum', 'saying', 'eligible', 'covid', 'vaccine', 'appointment', 'best', 'vaccine']\n"],
#  [1364880845203529730,
#   b"['good morning', 'blessing', 'grace', 'peace', 'sweet', 'friends', 'turn', 'coronavirus', 'vaccine', 'hospital', 'promised', 'hurt', 'playing', 'happy', 'love', 'vaccine', 'covid']\n"],
#  [1375837654567239684,
#   b"['friendly', 'neighborhood', 'vaccine', 'sign', 'released', 'lots', 'vaccine', 'vaccine']\n"],
#  [1365275489875689475,
#   b"['wait for', 'vaccine', 'process', 'quick', 'organized', 'vaccine', 'huge', 'pussy', 'injection', 'brave', 'sausage', 'covid', 'vaccine', 'vaccine']\n"],
#  [1365189458073505792,
#   b"['go for', 'worry about', 'houre', 'fever', 'subside', 'weakness', 'rest', 'fine', 'nothing', 'vaccine', 'turn', 'covid', 'vaccine']\n"],
#  [1345929479563055104,
#   b"['forget', 'vaccine', 'wanted', 'creating', 'furor', 'aim', 'covid', 'vaccine', 'emerged', 'vaccine']\n"],
#  [1367873796380721152,
#   b"['teach', 'covid', 'vaccine', 'federal', 'pharmacy', 'locate']\n"],
#  [1346068751406387201, b"['phase', 'efficacy', 'expected', 'vaccine']\n"],
#  [1359535069942185990,
#   b"['paid to', 'covid', 'vaccine', 'new', 'variant', 'missing', 'look', 'late', 'approving', 'vaccine', 'useless']\n"],
#  [1355215644971642880,
#   b"['phenomenal', 'proud', 'admin', 'volunteer', 'community', 'vaccine', 'covid']\n"],
#  [1355233965108506627,
#   b"['happy', 'happy', 'end', 'mum', 'vaccine', 'sunday', 'vaccine']\n"],
#  [1373213442497249280,
#   b"['i want', 'lung transplant', 'shame on', 'tested positive', 'take', 'look', 'loue', 'double', 'patient', 'administer', 'vaccine', 'healthy']\n"],
#  [1361669253116624901,
#   b"['lawsuit', 'infringement', 'protein', 'trial', 'covid', 'vaccine', 'exemplify', 'barrier', 'show', 'needed', 'allele', 'biotechnology', 'pharmaceutical']\n"],
#  [1376758344371728385,
#   b"['work on', 'vax', 'everywhere', 'educated', 'constantly', 'vaccine', 'education', 'awareness', 'increase', 'acceptability', 'possible', 'vaccine']\n"],
#  [1362444117939265539,
#   b"['shift', 'volunteer', 'pry', 'house', 'vaccine', 'happy', 'help', 'vaccine']\n"],
#  [1353904834970341376,
#   b"['remember', 'grandma', 'crying', 'pandemic', 'worse', 'vaccine', 'save', 'late', 'died', 'stay', 'apart', 'together', 'late', 'late', 'vaccine', 'vaccine']\n"],
#  [1367577827151855617,
#   b"['vaccine', 'available', 'vaccine', 'battle', 'against', 'covid', 'dose']\n"],
#  [1376593401156677639,
#   b"['govern', 'new', 'eligibility', 'covid', 'vaccine', 'new', 'old', 'receive', 'covid', 'vaccine']\n"],
#  [1349751712920330240,
#   b"['vaccine', 'nation', 'uniform', 'scrub', 'vaccine', 'say', 'training', 'help', 'vaccine']\n"],
#  [1356669152434524162,
#   b"['plummet', 'vaccine', 'distribution', 'failure', 'unemployment', 'check', 'failure', 'economy', 'ouch']\n"],
#  [1375200605275357186,
#   b"['renowned', 'virologist', 'shares', 'latest', 'covid', 'vaccine', 'rollout', 'better', 'prepare', 'against', 'pandemic']\n"],
#  [1358052832088182785, b"['stole', 'full', 'covid', 'vaccine', 'vaccine']\n"],
#  [1376073216607813632,
#   b"['fortune teller', 'conspiracy theorist', 'call', 'covid', 'mask', 'vaccine']\n"],
#  [1368479274169110529,
#   b"['ready to', 'believe', 'covid', 'vaccine', 'good', 'vaccine', 'nationalism', 'reject', 'attempt', 'politicize', 'cooperation', 'vaccine', 'work', 'ioc', 'provide', 'vaccine', 'olympian']\n"],
#  [1351867448228769793,
#   b"['new', 'communicate', 'clear', 'goal', 'needed', 'achieve', 'detail', 'vaccine', 'plan', 'transparency', 'clarity', 'mobilize', 'community', 'combine', 'move', 'pandemic']\n"],
#  [1363701213192019970,
#   b"['go ahead', 'approve', 'covid', 'vaccine', 'emergency']\n"],
#  [1375211455956578304,
#   b"['old', 'helping', 'new', 'vaccine', 'appointments']\n"],
#  [1346156746012839948,
#   b"['best thing', 'vaccine', 'probable', 'protect', 'associate', 'emergency', 'medicine', 'medical', 'cent', 'defense', 'urge', 'wear', 'mask']\n"],
#  [1362771112631947268, b"['turn', 'register', 'covid', 'vaccine']\n"],
#  [1351884497952894976,
#   b"['lose sight', 'careful', 'clinical', 'vulnerability', 'vaccine', 'prioritise']\n"],
#  [1347223458283986944, b"['thanks', 'covid', 'vaccine', 'dose']\n"],
#  [1350117166813741056,
#   b"['call', 'covid', 'vaccine', 'confusing', 'touches', 'malevolent', 'false', 'claim', 'spare', 'vaccine', 'army', 'terminal']\n"],
#  [1357730048908947456,
#   b"['well done', 'moth', 'daughter', 'admin', 'awesome', 'important', 'personally', 'admin', 'difficult', 'vaccine']\n"],
#  [1345458096504778759,
#   b"['suit', 'dance', 'last', 'dose', 'covid', 'vaccine', 'vaccine']\n"],
#  [1345204617001447425,
#   b"['covid', 'vaccine', 'consistent', 'recent', 'survey', 'healthcare', 'vaccine', 'hesitant']\n"],
#  [1369404732998098947,
#   b"['medical provider', 'widen', 'vaccine', 'eligibility', 'certa', 'medical', 'see', 'eligibility', 'designee', 'input', 'information', 'database', 'patient', 'compile', 'upload']\n"],
#  [1358814536854339595,
#   b"['early on', 'b day', 'targets', 'scorecards', 'dose', 'average', 'take', 'dose', 'debt', 'vaccine']\n"],
#  [1355940919699251202,
#   b"['dose', 'covid', 'vaccine', 'amazing', 'hate', 'quarantine', 'say', 'comfortable', 'process', 'autism']\n"],
#  [1365612163268808704,
#   b"['dose', 'wait', 'within', 'bam', 'thank', 'vaccine']\n"],
#  [1376794267084075008,
#   b"['misunderstand', 'problem', 'vaccine', 'defend', 'stop', 'fighting', 'against', 'freedom', 'live', 'freely', 'covid', 'vaccine']\n"],
#  [1374389993053900805,
#   b"['happy', 'stir', 'vaccine', 'liar', 'develop', 'happy', 'covid', 'dead', 'try', 'hide', 'slump', 'causing']\n"],
#  [1349083995749949444, b"['dose', 'covid', 'vaccine']\n"],
#  [1372164354620162049,
#   b"['sticker', 'cheering', 'dancing', 'drive', 'home', 'vaccine', 'vaccine']\n"],
#  [1356351151025881090,
#   b"['covid', 'vaccine', 'easy', 'vaccine', 'sign', 'share', 'petition', 'stop', 'shooting', 'badger']\n"],
#  [1347459373459767296,
#   b"['impressed', 'proactive', 'surgery', 'vaccine', 'needed']\n"],
#  [1373188297447514114, b"['lightheaded', 'wobbly', 'vaccine']\n"],
#  [1358936274925715456,
#   b"['vaccine', 'delay', 'adjuvant', 'relate', 'fault', 'report', 'gulp', 'apologize', 'best', 'crap', 'vaccine']\n"],
#  [1358512529325096974,
#   b"['deliver', 'nation', 'probable', 'drafted', 'speech', 'positive', 'hopeful', 'vaccine', 'arrival', 'rewrite', 'speech', 'vaccine']\n"],
#  [1371821870962577410,
#   b"['advising', 'vaccine', 'safe', 'suspend', 'selectively', 'copy', 'paste', 'advice', 'damn', 'live', 'covid', 'cancer']\n"],
#  [1355298807622344707, b"['walk into', 'vaccine', 'yes', 'double']\n"],
#  [1347852319401021441,
#   b"['diseases', 'control', 'essential', 'forgotten', 'pose', 'threat', 'thanks', 'vaccine', 'vaccine', 'vaccine']\n"],
#  [1368242142200487939,
#   b"['vaccine', 'stop', 'virus', 'decrease', 'severity', 'covid']\n"],
#  [1349816154701799426, b"['severe', 'vaccine', 'effects', 'vaccine']\n"],
#  [1359631920271884294,
#   b"['dose', 'effects', 'manageable', 'tylenol', 'hesitant', 'remember', 'fine', 'scary', 'present', 'majority', 'vaccine', 'coronavirus']\n"],
#  [1373901117537484801,
#   b"['vaccine', 'covid', 'important', 'tool', 'safe', 'dose', 'vaccine', 'urge', 'eligible', 'vaccine', 'ideal', 'beat', 'pandemic']\n"],
#  [1364645359033679880,
#   b"['saa', 'flying', 'fetch', 'batch', 'vaccine', 'vaccine']\n"],
#  [1345790612746903552,
#   b"['best journal', 'balance', 'give', 'approval', 'vaccine', 'certification', 'give', 'approval', 'idiots', 'vaccine']\n"],
#  [1363185032794374144, b"['care', 'vaccine', 'colleague', 'vaccine']\n"],
#  [1359912222231826433,
#   b"['covid', 'vaccine', 'happy', 'thank', 'lovely', 'volunteer', 'brilliant', 'job', 'vaccine']\n"],
#  [1361430083957907457,
#   b"['tested positive', 'covid', 'receiving', 'dose', 'vaccine', 'health', 'vaccine', 'efficacy', 'breakthrough', 'expected']\n"],
#  [1375131311048945667,
#   b"['vaccine', 'imagine', 'room', 'surreal', 'emotional']\n"],
#  [1360263389818335236,
#   b"['early on', 'b day', 'targets', 'scorecards', 'dose', 'average', 'goal', 'predict', 'vaccine']\n"],
#  [1367497631010861065,
#   b"['turn', 'offer', 'vaccine', 'accept', 'rightfully', 'perfect', 'enemy', 'good', 'covid']\n"],
#  [1369728798342676483,
#   b"['delighted', 'report', 'vaccine', 'thanks', 'efficient', 'easy', 'painless', 'vaccine']\n"],
#  [1356756331349295104,
#   b"['conclusion', 'infection', 'dose', 'covid', 'vaccine', 'follow', 'boost', 'antibody', 'fallacy', 'false', 'antibody', 'immunity']\n"],
#  [1353396147004600320,
#   b"['vaccine', 'dose', 'within', 'last', 'houre', 'new', 'record', 'tote', 'vaccine', 'dose', 'dose', 'follow', 'live', 'coronavirus', 'update']\n"],
#  [1349230771416961026, b"['direct', 'match', 'vaccine']\n"],
#  [1354443751305994240,
#   b"['explain', 'benefits', 'digital', 'health', 'vaccine', 'mutation', 'vaccine']\n"],
#  [1350498902840061952,
#   b"['make', 'sure', 'access', 'vaccine', 'thanks', 'volunteer', 'light', 'darkness', 'punch', 'vaccine']\n"],
#  [1345794368280662018,
#   b"['deal with', 'blocked', 'vax', 'simple', 'unblock', 'new', 'eve', 'hear', 'vaccine', 'save', 'live', 'vaccine', 'covid']\n"],
#  [1375252395299500034,
#   b"['plane', 'batch', 'vaccine', 'amid', 'rapid', 'surge', 'covid', 'infection', 'registered', 'vaccine']\n"],
#  [1360961323757150210,
#   b"['please stop', 'attacking', 'corrupt', 'call', 'vax', 'cherry', 'shares', 'vaccine', 'take', 'precedence', 'lesson', 'trace', 'crone', 'fiasco']\n"],
#  [1373348923859943424,
#   b"['proof', 'trusted', 'vaccine', 'works', 'supported', 'chuck', 'vaccine', 'reluctant', 'leaning', 'persuade', 'last', 'barrier', 'thank']\n"],
#  [1374374487420923904,
#   b"['report', 'clinical', 'covid', 'vaccine', 'protects', 'against', 'variant', 'refer', 'variant']\n"],
#  [1356799649319804932,
#   b"['open', 'vaccine', 'appointments', 'important', 'eye', 'key', 'factor', 'decision', 'open', 'vaccine', 'eligibility', 'covid', 'vaccine']\n"],
#  [1355132662223171588,
#   b"['bilateral relation', 'reflect', 'economic', 'trade', 'corona', 'vaccine']\n"],
#  [1363137443420114950,
#   b"['open', 'local', 'ask', 'support', 'vaccine', 'vaccine']\n"],
#  [1366812321155317761,
#   b"['senior pastor', 'community', 'sense', 'normalcy', 'take', 'vaccine', 'rev', 'art', 'covid', 'vaccine', 'champion']\n"],
#  [1363808814584184834,
#   b"['confirmed', 'medical', 'covid', 'vaccine', 'blamed', 'care']\n"],
#  [1347509278886797312,
#   b"['informative overview', 'translate', 'interesting', 'vaccine', 'vaccine']\n"],
#  [1370296017694949377,
#   b"['fake news', 'demonstrate', 'effectiveness', 'approved', 'worried', 'vaccine', 'forces']\n"],
#  [1359599540525957120,
#   b"['new version', 'released', 'guidance', 'vaccine', 'pharmaceutical', 'distribution', 'document', 'alert']\n"],
#  [1352339106362257416,
#   b"['hypochondria', 'arm', 'sore', 'favoring', 'remember', 'vaccine', 'arm', 'vaccine', 'covid', 'essential', 'veterinary']\n"],
#  [1353982823800205312,
#   b"['customs union', 'resonate', 'decision', 'pick', 'fight', 'status', 'hint', 'impose', 'tariff', 'vaccine', 'rogue', 'vaccine']\n"],
#  [1346552923375824897,
#   b"['update', 'dose', 'covid', 'vaccine', 'uncomfortable', 'muscle', 'ache', 'fatigue', 'headache', 'chill', 'better', 'pass', 'quickly', 'immune', 'system', 'stimulated']\n"],
#  [1352463753187483648, b"['strange', 'sense', 'relief', 'vaccine']\n"],
#  [1346803727064248322,
#   b"['control access', 'shuttered', 'indoor', 'shopping', 'malls', 'covid', 'vaccine', 'take', 'stay', 'build', 'observe', 'transit', 'space', 'vaccine']\n"],
#  [1351117847523684352,
#   b"['district', 'collector', 'vaccine', 'effort', 'motivate', 'vaccine', 'covid']\n"],
#  [1372192366765993984,
#   b"['excite', 'covid', 'immunization', 'clinic', 'open', 'vaccine', 'pleased', 'visit', 'clinic', 'loved', 'eligible', 'vaccine']\n"],
#  [1355346696683876356,
#   b"['nothing', 'unity', 'mastermind', 'skip', 'covid', 'vaccine']\n"],
#  [1349340783334158342, b"['vaccine', 'vaccine']\n"],
#  [1354162040009617410,
#   b"['think about', 'amplify', 'comment', 'develop', 'infectious', 'covid', 'vaccine', 'vaccine']\n"],
#  [1355107929674944513,
#   b"['turn up', 'good luck', 'see', 'beat', 'last', 'record', 'understand', 'appointment', 'room', 'hopefully', 'needle', 'end', 'winning', 'vaccine']\n"],
#  [1367153078160527361,
#   b"['vaccine', 'vaccine', 'hoarding', 'vaccine', 'wrong', 'vaccine', 'fast', 'tracking', 'vaccine', 'honestly', 'mix', 'board', 'ridiculous', 'vaccine']\n"],
#  [1347908961211539456,
#   b"['thanks', 'vaccine', 'appointment', 'moth', 'appointments', 'available']\n"],
#  [1365310779797491716, b"['call', 'mess', 'vaccine']\n"],
#  [1357330763541327872,
#   b"['liver cancer', 'prostate cancer', 'great', 'idea', 'add', 'cancer', 'cancer', 'institute', 'vaccine', 'chemotherapy']\n"],
#  ...]

# %%
# for i in range(len(outputs)):    
#     outputs[i][1] = outputs[i][1].decode("utf-8")[:-1]
# # map outputs to pandas
# for i in range(len(outputs)):
#     data.loc[data['id'] == outputs[i][0], 'concept_api_output'] = outputs[i][1]

# %%
# data.to_csv('gold_raw.csv')
